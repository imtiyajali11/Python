# %%
# sum of numbers of given list

# %%
a = [12,3,4,55,6]
total = 0

for i in a:
    total= sum(a)
print(total)
# Out:
# 80

# %%
a = [12,3,4,55,6]
b = 0

for i in range(len(a)):
    b = b+ i
print(b)
# Out:
# 10

# %%
# count values

a = [12,3,4,55,6]
b = 0

for i in a:
    b = i + 1
print(b)
# Out:
# 7

# %%
# a = sum of integer
a = [1,3,5,'asdf' , 123.3]

b = 0 

for i in a:
    if type(i) == int:
        b = b + i
        print(i)
print(b)
# Out:
# 1
# 3
# 5
# 9

# %%
# sum of int. and float

a = [1,3,5,'asdf' , 123.3]

b = 0 

for i in a:
    if type(i) == int or type(i) == float: 
        b = b + i
        print(i)
print(b)
# Out:
# 1
# 3
# 5
# 123.3
# 132.3

# %%
# 
a = ['1','3','5','12']
b = 0 


for i in a:
    i = int(i)
    if type(i) == int:
        b = b + i
        print(i)
print(b)
# Out:
# 1
# 3
# 5
# 12
# 21

# %%
# check if the valid decimal or not

a = '2345.1234'

b = '235'


if '.' in a:
    a = a.replace('.','')
    if a.isnumeric():
        print('valid')
    else:
        print('invalid')
else:
    print('invalid decimal')
# Out:
# valid
