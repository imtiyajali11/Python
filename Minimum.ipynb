# %% [markdown]
# # min of 3 numbers

# %%
# Input

a = 10
b = 1
c = 10

# %%
if a < b and a < c:
    print('a is the smallest one:', a)
elif b< a and b < c:
    print('b is the smallest one:', b)
elif c< a and c < b :
    print('c is the smallest one:', c)
else:
    print('a,b, & c all have same value:', a, b, c)
# Out:
# b is the smallest one: 1
