# %% [markdown]
# # control flow statements
# # pass
# pass - its place holder, it will skip the step and won't throw error, to avoid error in the line of code.
# # continue
# # break

# %% [markdown]
# #
