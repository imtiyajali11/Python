# %%
# funcitons: inbuilt(readymade) and user defined

# ex. sum, min, max, abs


# 1. check if the no. is +ve, -ve or zero

a = [1,4,6,0,-1,-2]

for i in a:
    if i%2 == 0:
        print('+ve no')
    else:

# %%
a = 234

if a> 0 :
    print('+ve no.')
elif a < 0:
    print('-ve no.') 
else:
   print('zero')
# Out:
# +ve no.

# %%
#def validp(): if no value given in the box, then its parameter less funcitons

def validp(a):           # parameterised function
    if a> 0 :
        print('+ve no.')
    elif a < 0:
        print('-ve no.') 
    else:
        print('Zero')

# %%
validp(0)
# Out:
# Zero
