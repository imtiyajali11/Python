# %%
# check if the number is odd or even

a = 12

if a%2==0:
    print ('Even')
else:
    print('odd')
# Out:
# Even

# %%
def OdEn(a):
    if a%2==0:
        print ('Even')
    else:
        print('odd')

# %%
OdEn(-13)
# Out:
# odd
