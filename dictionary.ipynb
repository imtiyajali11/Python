# %% [markdown]
# # Dictionary

# %%
d = {'a': 234.1, 1: 'aniket', (1,1,3): [23,4,23,23]}
d
# Out:
# {'a': 234.1, 1: 'aniket', (1, 1, 3): [23, 4, 23, 23]}

# %%
d = { 1:'a', 'b': 2, 'c': 4}
d
# Out:
# {1: 'a', 'b': 2, 'c': 4}

# %%
type(d)
# Out:
# dict

# %%
d['b'], d[1], d['c']
# Out:
# (2, 'a', 4)

# %%
d= {'i': 5}

# %%
d[1] = 1000
d
# Out:
# {'i': 5, 1: 1000}

# %%
d
# Out:
# {'i': 5, 1: 1000}

# %%
d['j'] = 56
d
# Out:
# {'i': 5, 1: 1000, 'j': 56}

# %%
d.values(), d.keys()
# Out:
# (dict_values([5, 1000, 56]), dict_keys(['i', 1, 'j']))

# %%
d.items()
# Out:
# dict_items([('i', 5), (1, 1000), ('j', 56)])

# %%
d.get(1)
# Out:
# 1000

# %%
d.pop(1)
# Out:
# 1000

# %%
d
# Out:
# {'i': 5, 'j': 56}

# %%
d.popitem()
# Out:
# ('j', 56)

# %%
d
# Out:
# {'i': 5}

# %%
d['roll no'] = 10

# %%
d
# Out:
# {'i': 5, 'roll no': 10}

# %%
d.update({'marks': 45, 'age': 21})

# %%
d
# Out:
# {'i': 5, 'roll no': 10, 'marks': 45, 'age': 21}
