# %%
# diff between print and return
# sum of numbers of given list

def sum_(a):
    s = 0
    for  i in a:
        s += i
    print(s)

# %%
sum_(a=[12,34,12,1,1])
# Out:
# 60

# %%
a = [12,12,12,12]
s = 0
for  i in a:
    s += i
print(s)
# Out:
# 48
