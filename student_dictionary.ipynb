# %%
student = {
    "name": "Aarav",
    "age": 16,
    "grade": "10th",
    "city": "Mumbai",
    "marks": {
        "Math": 88,
        "Science": 92,
        "English": 85
    },
    "hobbies": ["Cricket", "Reading", "Coding"]
}

# %%
student
# Out:
# {'name': 'Aarav',
#  'age': 16,
#  'grade': '10th',
#  'city': 'Mumbai',
#  'marks': {'Math': 88, 'Science': 92, 'English': 85},
#  'hobbies': ['Cricket', 'Reading', 'Coding']}

# %%
# what is the name of the students

student['name']
# Out:
# 'Aarav'

# %%
# in which city the student lives?

student[('city')]
# Out:
# 'Mumbai'

# %%
# how many marks he got in math
student['marks']
# Out:
# {'Math': 88, 'Science': 92, 'English': 85}

# %%
student['marks']['Math']
# Out:
# 88

# %%
student['marks']['English']
# Out:
# 85

# %%
students = {
    'Aarav':{
        "name": "Aarav",
        "age": 16,
        "grade": "10th",
        "city": "Mumbai",
        "marks": {"Math": 88, "Science": 92, "English": 85},
        "hobbies": ["Cricket", "Reading", "Coding"]
    },
    'Priya':{
        "name": "Priya",
        "age": 15,
        "grade": "10th",
        "city": "Pune",
        "marks": {"Math": 95, "Science": 89, "English": 90},
        "hobbies": ["Swimming", "Painting"]
    },
    'Rohan':{
        "name": "Rohan",
        "age": 17,
        "grade": "11th",
        "city": "Delhi",
        "marks": {"Math": 78, "Science": 82, "English": 88},
        "hobbies": ["Football", "Gaming", "Music"]
    }
}

# %%
type(student)
# Out:
# dict

# %%
students = [
    {
        "name": "Aarav",
        "age": 16,
        "grade": "10th",
        "city": "Mumbai",
        "marks": {"Math": 88, "Science": 92, "English": 85},
        "hobbies": ["Cricket", "Reading", "Coding"]
    },
    {
        "name": "Priya",
        "age": 15,
        "grade": "10th",
        "city": "Pune",
        "marks": {"Math": 95, "Science": 89, "English": 90},
        "hobbies": ["Swimming", "Painting"]
    },
    {
        "name": "Rohan",
        "age": 17,
        "grade": "11th",
        "city": "Delhi",
        "marks": {"Math": 78, "Science": 82, "English": 88},
        "hobbies": ["Football", "Gaming", "Music"]
    }
]

type(students)
# Out:
# list

# %%
# how many students we have?

len(students)
# Out:
# 3

# %%
for i in students:
    print(i)
# Out:
# {'name': 'Aarav', 'age': 16, 'grade': '10th', 'city': 'Mumbai', 'marks': {'Math': 88, 'Science': 92, 'English': 85}, 'hobbies': ['Cricket', 'Reading', 'Coding']}
# {'name': 'Priya', 'age': 15, 'grade': '10th', 'city': 'Pune', 'marks': {'Math': 95, 'Science': 89, 'English': 90}, 'hobbies': ['Swimming', 'Painting']}
# {'name': 'Rohan', 'age': 17, 'grade': '11th', 'city': 'Delhi', 'marks': {'Math': 78, 'Science': 82, 'English': 88}, 'hobbies': ['Football', 'Gaming', 'Music']}

# %%
# find out the name of the students.

for i in students:
    print(i['name'],i['age'],i['marks'])
# Out:
# Aarav 16 {'Math': 88, 'Science': 92, 'English': 85}
# Priya 15 {'Math': 95, 'Science': 89, 'English': 90}
# Rohan 17 {'Math': 78, 'Science': 82, 'English': 88}

# %%
for i in students:
    print(i['name'],i['age'],i['marks']['English'])
# Out:
# Aarav 16 85
# Priya 15 90
# Rohan 17 88

# %%
# find out the names of the students and the city in which they live


for i in students:
    print(i['name'],i['city'])
    print('*' * 40)
# Out:
# Aarav Mumbai
# ****************************************
# Priya Pune
# ****************************************
# Rohan Delhi
# ****************************************

# %%
i = 0
while i in students:
    print(i['name'], i['city'])
    i +=1

# %%
# find out the student who's age is 16

for i in students:
    if i['age'] == 16:
        print(i['name'])
# Out:
# Aarav

# %%
students
# Out:
# [{'name': 'Aarav',
#   'age': 16,
#   'grade': '10th',
#   'city': 'Mumbai',
#   'marks': {'Math': 88, 'Science': 92, 'English': 85},
#   'hobbies': ['Cricket', 'Reading', 'Coding']},
#  {'name': 'Priya',
#   'age': 15,
#   'grade': '10th',
#   'city': 'Pune',
#   'marks': {'Math': 95, 'Science': 89, 'English': 90},
#   'hobbies': ['Swimming', 'Painting']},
#  {'name': 'Rohan',
#   'age': 17,
#   'grade': '11th',
#   'city': 'Delhi',
#   'marks': {'Math': 78, 'Science': 82, 'English': 88},
#   'hobbies': ['Football', 'Gaming', 'Music']}]

# %%
# how many students are in 10th
count = 0
for i in students:
    if i['grade'] == '10th':
        count += 1
        print(count, i['name'])
print('Student count studying in 10th:',count)
# Out:
# 1 Aarav
# 2 Priya
# Student count studying in 10th: 2

# %%
# find out the total marks of each students

total = 0

for i in students:
    total = i['marks']['Math']+i['marks']['Science']+i['marks']['English']
    #print(i['name'])
    #print(i['marks'])
    print(i['name'],total)
# Out:
# Aarav 265
# Priya 274
# Rohan 248

# %%
# Out:
# 0 [2, 3, 5, 6, 4, 3, 2, 4, 5]
# 1 [2, 3, 5, 6, 4, 3, 2, 4, 5]
# 2 [2, 3, 5, 6, 4, 3, 2, 4, 5]
# 3 [2, 3, 5, 6, 4, 3, 2, 4, 5]
# 4 [2, 3, 5, 6, 4, 3, 2, 4, 5]
# 5 [2, 3, 5, 6, 4, 3, 2, 4, 5]
# 6 [2, 3, 5, 6, 4, 3, 2, 4, 5]

# %%
# find out the avg marks of each student

total = 0

for i in students:
    total = (i['marks']['Math']+i['marks']['Science']+i['marks']['English'])/3
    #print(i['name'])
    #print(i['marks'])
    print(i['name'],total)
# Out:
# Aarav 88.33333333333333
# Priya 91.33333333333333
# Rohan 82.66666666666667

# %%
for i in students:
    print(i['name'], sum(i['marks'].values())/len(i['marks']))
# Out:
# Aarav 88.33333333333333
# Priya 91.33333333333333
# Rohan 82.66666666666667
