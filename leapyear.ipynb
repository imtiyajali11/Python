# %% [markdown]
# # leap year

# %%
#input

year = 2027

# %%
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print('This year is leap year:', year)
else:
    print('This is not leap year:', year)
# Out:
# This is not leap year: 2027
