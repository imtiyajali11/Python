# %%
#create a function to check if the number is valid decimal or not
# check if the number is odd or even
# print the table of any number

# %%
a = '1232.2'

if '.' in a:
    a = a.replace('.','')
    if a.isnumeric():
        print('valid decimal')
    else:
        print('Invalid decimal')
else:
    print('invalid decimal')
# Out:
# valid decimal

# %%
def validDec(a):

    if '.' in a:
        a = a.replace('.','')
        if a.isnumeric():
            print('valid decimal')
        else:
            print('Invalid decimal')
    else:
        print('invalid decimal')

# %%
validDec('123.2')
# Out:
# valid decimal

# %%
def ValidDecNum(a):
    if type(a) == float:
        print(a)
    else:
        print('invalid')

# %%
a = 12.2
if type(a) == float:
    print(a)
# Out:
# 12.2

# %%
ValidDecNum(12.2)
# Out:
# 12.2

# %%
# print the table of any number

a = 12

for i in range(1,11):
    print(i*a)
# Out:
# 12
# 24
# 36
# 48
# 60
# 72
# 84
# 96
# 108
# 120

# %%
def multable(a):
    for i in range(1,11):
        print(i*a)

# %%
multable(20)
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
