# %%
# List Questions
# Create a list of 5 numbers and print each number using a for loop.
# Find the sum of all numbers in a list using a loop.
# Print only the even numbers from a list.
# Count how many numbers are greater than 10 in a list.
# Find the largest number in a list using a loop.
# Create a list of names and print each name in uppercase using a loop.
   
# Tuple Questions
# Create a tuple of 5 numbers and print each element using a loop.
# Find the sum of all elements in a tuple.
# Count how many times a specific number appears in a tuple using a loop.
# Print only the odd numbers from a tuple.
# Find the smallest value in a tuple using a loop.
   
# Set Questions
# Create a set of numbers and print all elements using a loop.
# Count how many elements are present in a set using a loop.
# Print only numbers greater than 20 from a set.
# Find the sum of all values in a set using a loop.
# Print the square of each element in a set.
   
# Dictionary Questions
# Create a dictionary with student names and marks. Print all keys using a loop.
# Create a dictionary with student names and marks. Print all values using a loop.
# Print both key and value from a dictionary using a loop.
# Create a dictionary of 5 products and their prices. Find the total price of all products using a loop.

# Bonus Questions
# Count how many vowels are present in a list of characters.
# Find the average of numbers stored in a tuple.
# Print all unique elements from a list using a set and loop.
# Create a dictionary of employees and salaries. Print employees earning more than ₹50,000.
# Find the longest word from a list of words using a loop.

# %% [markdown]
# <!-- List Questions
# Create a list of 5 numbers and print each number using a for loop.
# Find the sum of all numbers in a list using a loop.
# Print only the even numbers from a list.
# Count how many numbers are greater than 10 in a list.
# Find the largest number in a list using a loop.
# Create a list of names and print each name in uppercase using a loop.
#
# Tuple Questions
# Create a tuple of 5 numbers and print each element using a loop.
# Find the sum of all elements in a tuple.
# Count how many times a specific number appears in a tuple using a loop.
# Print only the odd numbers from a tuple.
# Find the smallest value in a tuple using a loop.
#
# Set Questions
# Create a set of numbers and print all elements using a loop.
# Count how many elements are present in a set using a loop.
# Print only numbers greater than 20 from a set.
# Find the sum of all values in a set using a loop.
# Print the square of each element in a set.
#
# Dictionary Questions
# Create a dictionary with student names and marks. Print all keys using a loop.
# Create a dictionary with student names and marks. Print all values using a loop.
# Print both key and value from a dictionary using a loop.
# Create a dictionary of 5 products and their prices. Find the total price of all products using a loop.
#
# Bonus Questions
# Count how many vowels are present in a list of characters.
# Find the average of numbers stored in a tuple.
# Print all unique elements from a list using a set and loop.
# Create a dictionary of employees and salaries. Print employees earning more than ₹50,000.
# Find the longest word from a list of words using a loop. -->

# %% [markdown]
# <!-- List Questions
# Create a list of 5 numbers and print each number using a for loop.
# Find the sum of all numbers in a list using a loop.
# Print only the even numbers from a list.
# Count how many numbers are greater than 10 in a list.
# Find the largest number in a list using a loop.
# Create a list of names and print each name in uppercase using a loop.
#
# Tuple Questions
# Create a tuple of 5 numbers and print each element using a loop.
# Find the sum of all elements in a tuple.
# Count how many times a specific number appears in a tuple using a loop.
# Print only the odd numbers from a tuple.
# Find the smallest value in a tuple using a loop.
#
# Set Questions
# Create a set of numbers and print all elements using a loop.
# Count how many elements are present in a set using a loop.
# Print only numbers greater than 20 from a set.
# Find the sum of all values in a set using a loop.
# Print the square of each element in a set.
#
# Dictionary Questions
# Create a dictionary with student names and marks. Print all keys using a loop.
# Create a dictionary with student names and marks. Print all values using a loop.
# Print both key and value from a dictionary using a loop.
# Create a dictionary of 5 products and their prices. Find the total price of all products using a loop.
#
# Bonus Questions
# Count how many vowels are present in a list of characters.
# Find the average of numbers stored in a tuple.
# Print all unique elements from a list using a set and loop.
# Create a dictionary of employees and salaries. Print employees earning more than ₹50,000.
# Find the longest word from a list of words using a loop. -->
