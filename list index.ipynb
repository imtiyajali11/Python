# %%
a = [100,3,45,45,45,2345]

a
# Out:
# [100, 3, 45, 45, 45, 2345]

# %%
b = a.copy()

# %%
#convert list to tupple and tupple to list

f = [23,234,1,5,7,8]

g = (2,4,5,7,8)

type(f), type(g)
# Out:
# (list, tuple)

# %%
tuple(f), list(g)
# Out:
# ((23, 234, 1, 5, 7, 8), [2, 4, 5, 7, 8])

# %%
g.index(4), g.count(5)
# Out:
# (1, 1)

# %% [markdown]
# # sum of all the numbers present in the list
# # count of values in a list
# # sum all +ve number in a list
# # sum all even numbers in a list
# # count of  characters in a list
# # reverse a list
# # common between 2 list
