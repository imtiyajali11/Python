# %% [markdown]
# # File Handling

# %%
# Os module

import os

# %%
os.getcwd()
# Out:
# '/Users/alismac/Documents/ITVEDANT/Python/OOPs'

# %%
os.listdir()
# Out:
# ['pillars of oops.ipynb',
#  'oops_advance_calculator.ipynb',
#  'OOPs polymorphism parent child.ipynb',
#  'file_handling.ipynb',
#  'OOPs.ipynb',
#  'Unlocking Object Functionality.pdf',
#  'oops_calculator.ipynb',
#  'Except exception error.ipynb',
#  'OOPs Magic Methods(Dunder Methods).ipynb',
#  'OOPs_encapsulation.ipynb',
#  'Unlocking Object Functionality II.pdf']
