# %% [markdown]
# # reverse a list

# %%
a = ['ali', 3, 'imti', 4, 'shaikh', 5]
a
# Out:
# ['ali', 3, 'imti', 4, 'shaikh', 5]

# %%
i     = 0
j     = 0
count = 0
list  = []

while i < len(a):
    for j in range(0, i):
        list = a[i]
        j += 1
    i += 1
print(list)
# Out:
# 5

# %%
i = len(a) - 1
j = 0
reversed_list = []
count = 0

while i >= j:
    reversed_list.append(a[i])
    i -= 1
print(reversed_list)
# Out:
# [5, 'shaikh', 4, 'imti', 3, 'ali']

# %%
a.reverse()
print(a)
# Out:
# [5, 'shaikh', 4, 'imti', 3, 'ali']

# %%
b = a[::-1]
b
# Out:
# [5, 'shaikh', 4, 'imti', 3, 'ali']

# %%
a[::-1]
# Out:
# [5, 'shaikh', 4, 'imti', 3, 'ali']

# %%
a = ['ali', 3, 'imti', 4, 'shaikh', 5]
i = 0
count = 0
lst = []

while i < len(a):
    for j in range(len(a)-1,-1,-1):
        lst = a[i]
    
        j -= 1
    i += 1
print(a, lst)
# Out:
# ['ali', 3, 'imti', 4, 'shaikh', 5] 5
