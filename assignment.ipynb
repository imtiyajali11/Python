# %% [markdown]
# 1. Print Even Numbers from 1 to 20
# Use a and to print all even numbers between 1 and 20.
# 2
# 4
# 6
# ...
# 20
#
# 2. Print Odd Numbers from 1 to N
# Take a number N from the user and print all odd numbers up to N using a .
# 10
#
# 1
# 3
# 5
# 7
# 9
#
# 3. Count Positive Numbers
# Given a list of numbers, use a and to count how many numbers are positive.
# [5, -2, 8, -1, 0, 7]
#
# 3
#
# 4. Sum of Even Numbers from 1 to N
# Take N as input and find the sum of all even numbers between 1 and N.
# 10
#
# 30
#
# 5. Print Multiples of 5
# Use a to print all numbers from 1 to 50 that are divisible by 5.
# 5 10 15 20 25 30 35 40 45 50
#
# 6. Password Check
# Ask the user to enter a password repeatedly using a until they enter "admin123".
# Enter Password: test
# Wrong Password
#
# Enter Password: admin123
# Access Granted
#
# 7. Find Largest Number
# Given a list of numbers, use a and to find the largest number.
# [12, 45, 7, 89, 34]
#
# 89
#
# 8. Count Digits in a Number
# Take a number from the user and count how many digits it contains using a .
# 12345
#
# 5
#
# 9. Print Numbers Divisible by Both 3 and 5
# Use a and to print numbers between 1 and 100 that are divisible by both 3 and 5.
# 15 30 45 60 75 90
#
# 10. Number Guessing Game
# Store a secret number (e.g., 7). Use a to keep asking the user to guess until they enter the correct number.
# Guess: 3
# Wrong
#
# Guess: 5
# Wrong
#
# Guess: 7
# Correct!
# Bonus Challenge
#
#
#
# Print numbers from 1 to 50:
# If divisible by 3 → print "Fizz"
# If divisible by 5 → print "Buzz"
# If divisible by both → print "FizzBuzz"
# Otherwise print the number itself.
