# %% [markdown]
# # Problem Statement:
#     Web scrapping Men's shoes from Snapdeal

# %% [markdown]
# # Libraries

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas

# %%
# Web_url = "https://www.snapdeal.com/search?clickSrc=top_searches&keyword=shoes&categoryId=0&vertical=p&noOfResults=20&SRPID=topsearch&sort=rlvncy"

# Web_url = "https://www.snapdeal.com/search?clickSrc=top_searches&keyword=shoes&categoryId=0&vertical=p&noOfResults=20&SRPID=topsearch&sort=rlvncy"

# %%
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
response = requests.get(source_url, headers=headers)
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = requests.get(source_url, headers=headers)
#       2 response
#
# NameError: name 'source_url' is not defined
