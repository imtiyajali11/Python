# %%
# sum of all number fom 1 to 10

# %%
x = 10
total = 0

for i in range(0,11):
    total += i
print(total)
# Out:
# 55

# %%
N = 10
total = 0
i = 0

if i < N:
    total = total + i
    i += 1
print(total)
# Out:
# 0

# %%
# lambda
sum = lambda N :  total + i

# %%
sum(10)
# Out:
# 64

# %%
# count of all the number from 1 to 10

count = 0

for i in range(0,10):
    count += 1
print(count)
# Out:
# 10

# %%
# lambda
count = lambda x : len(i)

# %%
count(x)

# %%
word = ['apple', 'bat', 'cherry']
# find out the words having more than charac. 

[len(i) for i in word]
# Out:
# [5, 3, 6]

# %%
# find out the len of each word in given list
[len(i) for i in word]
# Out:
# [5, 3, 6]

# %%
# find out the owrds and their length in given list
{i: len(i) for i in word}
# Out:
# {'apple': 5, 'bat': 3, 'cherry': 6}

# %%
# find out the words and their len in given list if len > 3

{i:len(i) for i in word if len(i) > 3}
# Out:
# {'apple': 5, 'cherry': 6}

# %%
# find out the words and their len in given 
        # list if a is present in given word

a = ['ali', 'shaikh', 'eli']
b = []

for i in a:
    if 'a' not in i:
        b.append((i, len(i)))
print(b)
# Out:
# [('eli', 3)]

# %%
a = ['ali', 'eli','Ram', 'hritik','nishil','goel']
b = []

for i in a:
    if 'a' not in i:
        print(i, len(i))
# Out:
# eli 3
# hritik 6
# nishil 6
# goel 4
