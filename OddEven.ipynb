# %% [markdown]
# # Odd OR Even Number

# %%
Number = 4

# if Number == int:
if Number % 2 == 0:
    print('Even Number')
else:
    print('Odd Number')
# else:
#     print('Enter nummerical values only')
# Out:
# Even Number

# %%
# Need to get explanation for the isinstance

Number = 45.1


if isinstance(Number, int):
    if Number % 2 == 0:
        print("Even Number")
    else:
        print("Odd Number")
else:
        print("Enter integer values only")
# Out:
# Enter integer values only
