# %% [markdown]
# # Sets

# %%
s = {2, 34,5, 6, 7,4,5,6,3,2}        # set
l = [2,3,53,2,4]
t = (5,2,3,6,7,8)

# %%
type(s),type(l),type(t)
# Out:
# (set, list, tuple)

# %%
l[0], t[0]
# Out:
# (2, 5)

# %%
# s[0] can not be printed as it has no index

# %%
s
# Out:
# {2, 3, 4, 5, 6, 7, 34}

# %%
s.add(1)

# %%
s
# Out:
# {1, 3, 4, 5, 6, 7, 8, 9, 10, 34, 77, 100}

# %%
s.pop()
# Out:
# 3

# %%
s
# Out:
# {1, 4, 5, 6, 7, 8, 9, 10, 34, 77, 100}

# %%
s.update({3,4,5,6,77,7,7,8,8,8,9,9})
s
# Out:
# {3, 4, 5, 6, 7, 8, 9, 34, 77, 100}

# %%
a = {1,2,3,4}
b = {3,4,5,6}

# %%
a.intersection(b)          # common
# Out:
# {3, 4}

# %%
a.union(b)               # union or full join
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a.difference(b)         # present in a set but not in b set
# Out:
# {1, 2}

# %%
a.symmetric_difference(b)   # uncommon
# Out:
# {1, 2, 5, 6}

# %%
a.discard(1000)

# %%
s.remove(1000)

# %%
s.remove
# Out:
# <function set.remove(object, /)>

# %%
s
# Out:
# {1, 4, 5, 6, 7, 8, 9, 10, 34, 77, 100}

# %%
s.clear
# Out:
# <function set.clear()>

# %%
a.issubset(b)
# Out:
# False

# %%
a.issuperset(b)
# Out:
# False

# %%
a.difference(b), a.symmetric_difference(b)
# Out:
# ({1, 2}, {1, 2, 5, 6})

# %%
a.difference_update(b)

# %%
a
# Out:
# {1, 2}

# %%
a.update(b)

# %%
a
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a.intersection_update(b)

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
b
# Out:
# {3, 4, 5, 6}

# %%
a.symmetric_difference_update(b)

# %%
a
# Out:
# {1, 2, 5, 6}
