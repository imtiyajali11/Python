# %% [markdown]
# # File Handling

# %%
# Os module

import os

# %%
os.getcwd()
# Out:
# '/Users/alismac/Documents/ITVEDANT/Python/File handling'

# %%
os.listdir()
# Out:
# ['file_handling.ipynb']

# %%
os.mkdir('test')

# %%
os.listdir()
# Out:
# ['test', 'file_handling.ipynb', 't1']

# %%
os.makedirs("t1/t2/t3")        # To create folder into folder

# %%
os.rename('test', 'test1')

# %%
os.renames('t1/t2/t3', 't4/t5/t6')

# %%
os.listdir()
# Out:
# ['file_handling.ipynb']

# %%
os.getcwd()
# Out:
# '/Users/alismac/Documents/ITVEDANT/Python/File handling'

# %%
os.chdir('/Users/alismac/Documents/ITVEDANT/Python/File handling/test1')

# %%
os.listdir()
# Out:
# ['trying']

# %%
os.mkdir('trying')

# %%
os.chdir('/Users/alismac/Documents/ITVEDANT/Python/File handling/')

# %%
os.listdir()
# Out:
# ['file.txt', 'test', 'file_handling.ipynb', 'file=txt']

# %%
os.rmdir('file=txt')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 os.rmdir('file=txt')
#
# NotADirectoryError: [Errno 20] Not a directory: 'file=txt'

# %%
a = open('file.txt', 'w+')

# %%
os.listdir()
# Out:
# ['file.txt', 'test', 'file_handling.ipynb', 'file=txt']

# %%
with open('file.txt', 'r+') as f:
    l =f.read()
    print(l)
    f.close()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('file.txt', 'r+') as f:
    l = f.read()
    print(l)
    f.close()

# %%
a = open('file.txt', 'r+')
a.write('This is test file')
a.close()

# %%
lines = ['a', '\nb','\nC']
a = open('file.txt', 'w+')
a.writelines(lines)
a.close()

# %%
# Read
# No. of characters

with open('file.txt', 'r+') as a:
    l = a.read(1) 
    print(l)
    a.close()

# %%
# Read
# line
with open('file.txt', 'r+') as a:
    l = a.read(1)
    print(l)
    a.close()

# %%
# read
# Lines

with open('file.txt', 'r+') as a:
    l = a.read(1)
    print(l)
    a.close()

# %%
os.rename('f.txt', 'file.txt')
