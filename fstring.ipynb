# %% [markdown]
# # f string function

# %%
a = 234
print(f'the value of a is {a}')
# Out:
# the value of a is 234

# %%
# formatting method

print('the value of a is {}'.format(a))
# Out:
# the value of a is 234

# %%
# %d - decimal
# %s - string or charac
# %f - float
b = 111
print('the value of a is %s and %d'%(a,b))
# Out:
# the value of a is 234 and 111
